# %% [markdown]
# # Assignment 5

# %% [markdown]
# ## Exercise 1
# see notebook kMeansClustering.ipynb

# %% [markdown]
# ## Exercise 2
# ### 2.1
#
# ![IMG_20200604_155944.jpg](attachment:IMG_20200604_155944.jpg)

# %% [markdown]
# ### 2.2
# Not always the case. If the first seed point is $p_9$ and the same values for 𝜀 und $N_{min}$ are choosen $p_6$ belongs to Cluster $C_1 = \{ p_9, p_6, p_7, p_8, p_{10} \} $. Cluster Assignments depends on the first seed point

# %% [markdown]
# ### 2.3
#
# 𝜀 = 0.9
# $N_{min}$ = 2
#
# First Seed = $p_2$
#
# $C_1 = \{ p_2, p_4, p_5, p_3 \} $
#
# $C_2 = \{ p_1 \} $ -> noise
#
# $C_3 = \{ p_9, p_{10}, p_7 \} $
#
# $C_4 = \{ p_8, p_{11} \} $
#
# $C_5 = \{ p_6 \} $ -> noise

# %% [markdown]
# ### 2.4)
# |   | DBSCAN 	| kMean 	|
# |---|-----------|-----------------------	|
# | a | non-deterministic    	|    non-deterministic <br>(for random init)                    	|
# | b	| density-based      	|        centroid-based               	|
# | c	| 𝜀, $N_{min}$  	|             k (number of clusters)         	|
# | d	| 1 iteration  	|    $t_{max}$ iterations                  	|
# | e	| detects noise points     	| does not detect noise points                    	|

# %% [markdown]
# ### 2.5
# Clustering on DBSCAN works, because the distance between the points on the mouth, eyes and face is very small. All datapoints that belongs to cluster mouth have a small distance to each other. And the distance to the points from another cluster is very large.
#
# The k-means clustering fails because not the distance between individual points is relevant, but the distance of the individual points from the selected centroids.

# %% [markdown]
# ## Exercise 3
# see DBSCANParameters.ipynb
